# %% [markdown]
# # 0. ViT论文回顾
# ### 摘要：
# Transformer很强，但视觉任务中的应用还有限。ViT尝试将纯Transformer结构引入到CV的基本任务--图像分类中。
#
# 结构预览
#
# ![image-2.png](attachment:image-2.png)
# ### 讲解要点：
# 输入端适配, class token, positional encoding, Mutihead Attention, Transformer Encoder block 的实现
# ### 讲解方式：
# 通过数据流来展示输入图片是如何按照原理图一步一步转变成分类结果的
# ### Source code:
# https://github.com/lucidrains/vit-pytorch

# %% [markdown]
# # 0.1 通过程序入口定位核心代码
# ![image.png](attachment:image.png)

# %%
import torch
from torch import nn, einsum
import torch.nn.functional as F

from einops import rearrange, repeat
from einops.layers.torch import Rearrange

# helpers

def pair(t):
    return t if isinstance(t, tuple) else (t, t)

# classes

class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

class Attention(nn.Module):
    def __init__(self, dim, heads = 8, dim_head = 64, dropout = 0.):
        super().__init__()
        inner_dim = dim_head *  heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim = -1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        b, n, _, h = *x.shape, self.heads
        qkv = self.to_qkv(x).chunk(3, dim = -1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h = h), qkv)

        dots = einsum('b h i d, b h j d -> b h i j', q, k) * self.scale

        attn = self.attend(dots)

        out = einsum('b h i j, b h j d -> b h i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout = 0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(dim, Attention(dim, heads = heads, dim_head = dim_head, dropout = dropout)),
                PreNorm(dim, FeedForward(dim, mlp_dim, dropout = dropout))
            ]))
    def forward(self, x):
        for attn, ff in self.layers:
            x = attn(x) + x
            x = ff(x) + x
        return x

class ViT(nn.Module):
    def __init__(self, *, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, pool = 'cls', channels = 3, dim_head = 64, dropout = 0., emb_dropout = 0.):
        super().__init__()
        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)

        assert image_height % patch_height == 0 and image_width % patch_width == 0, 'Image dimensions must be divisible by the patch size.'

        num_patches = (image_height // patch_height) * (image_width // patch_width)
        patch_dim = channels * patch_height * patch_width
        assert pool in {'cls', 'mean'}, 'pool type must be either cls (cls token) or mean (mean pooling)'

        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1 = patch_height, p2 = patch_width),
            nn.Linear(patch_dim, dim),
        )

        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        self.dropout = nn.Dropout(emb_dropout)

        self.transformer = Transformer(dim, depth, heads, dim_head, mlp_dim, dropout)

        self.pool = pool
        self.to_latent = nn.Identity()

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, img):
        #print("img:", img.shape)
        x = self.to_patch_embedding(img)
        #print("x:", x.shape)
        
        b, n, _ = x.shape
        print("self.cls_token:", self.cls_token.shape)
        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b = b)
        print("cls_token:", cls_tokens.shape)
        x = torch.cat((cls_tokens, x), dim=1)
        #print("x:", x.shape)
        #x += self.pos_embedding[:, :(n + 1)]
        x += self.pos_embedding
        x = self.dropout(x)

        x = self.transformer(x)

        x = x.mean(dim = 1) if self.pool == 'mean' else x[:, 0]
        x = self.to_latent(x)
        return self.mlp_head(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a957f57ac194> in <module>
#       3 import torch.nn.functional as F
#       4
# ----> 5 from einops import rearrange, repeat
#       6 from einops.layers.torch import Rearrange
#       7
#
# ModuleNotFoundError: No module named 'einops'

# %%
import torch
#from vit_pytorch import ViT

v = ViT(
    image_size = 256,
    patch_size = 32,
    num_classes = 1000,
    dim = 1024,
    depth = 6,
    heads = 16,
    mlp_dim = 2048,
    dropout = 0.1,
    emb_dropout = 0.1
)

img = torch.randn(1, 3, 256, 256)

preds = v(img) # (1, 1000)
print(preds.shape)
# Out:
# self.cls_token: torch.Size([1, 1, 1024])
# cls_token: torch.Size([1, 1, 1024])
# torch.Size([1, 1000])

# %% [markdown]
# ### 0.2 参数
#
# - `image_size`: int.
# Image size. If you have rectangular images, make sure your image size is the maximum of the width and height
# - `patch_size`: int.
# Number of patches. `image_size` must be divisible by `patch_size`.
# The number of patches is: ` n = (image_size // patch_size) ** 2` and `n` **must be greater than 16**.
# - `num_classes`: int.
# Number of classes to classify.
# - `dim`: int.
# Last dimension of output tensor after linear transformation `nn.Linear(..., dim)`.
# - `depth`: int.
# Number of Transformer blocks.
# - `heads`: int.
# Number of heads in Multi-head Attention layer.
# - `mlp_dim`: int.
# Dimension of the MLP (FeedForward) layer.
# - `channels`: int, default `3`.
# Number of image's channels.
# - `dropout`: float between `[0, 1]`, default `0.`.
# Dropout rate.
# - `emb_dropout`: float between `[0, 1]`, default `0`.
# Embedding dropout rate.
# - `pool`: string, either `cls` token pooling or `mean` pooling
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. 输入端适配
# ### 1.1 图像切分重排
#
# 这一步的关键代码：

# %%
img = torch.randn(1, 3, 256, 256)
b = 1
c = 3
h = 256 = h * p1 , h = 8
w = 256

#patch_dim = p1 * p2 * c

self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1 = patch_height, p2 = patch_width), #图片切分重排
            nn.Linear(patch_dim, dim), # Linear Projection of Flattened Patches
        )

# %% [markdown]
# ### Rearrange? einops?
# einops是一个用来高效实现元素重排的库，主要用来代替一些需要集成使用reshape, repeat, expand, view, stack, permute才能实现的方法。恰好图片的切分重排就是这样的一个事情。
#
# 演示code：https://github.com/arogozhnikov/einops/blob/master/docs/1-einops-basics.ipynb

# %% [markdown]
# ### 1.2 构造patch0
#
# 这一步的关键代码：

# %%
# cls_tokens= (batch_size, cls_token = 1, dim)
# repeat是把class token复制b份 ， 假设，一个batch里面如果有8张图，那我需要8个class token。
# n是代表有多少个patch
cls_tokens = repeat(self.cls_token, '() n d -> b n d', b = b)
        x = torch.cat((cls_tokens, x), dim=1)

# %% [markdown]
# ### 1.3 positional enbedding
#
# 这一步的关键代码：

# %%
self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
x += self.pos_embedding[:, :(n + 1)]

# %% [markdown]
# # 2. Transformer Block
# 参数解析：
#
# 关键代码为：

# %%
x = self.transformer(x)

class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout = 0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(dim, Attention(dim, heads = heads, dim_head = dim_head, dropout = dropout)),
                PreNorm(dim, FeedForward(dim, mlp_dim, dropout = dropout))
            ]))
    def forward(self, x):
        for attn, ff in self.layers:
            x = attn(x) + x
            x = ff(x) + x
        return x

# %% [markdown]
# 这里面有三个封装好的类，PreNorm，Attention，FeedForward，我们对照Transformer Encoder结构图来讲解
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.1 PreNorm
# 关键代码：

# %%
class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

# %% [markdown]
# ### 2.2 MultiHead Attention
# 关键代码：

# %%
class Attention(nn.Module):
    def __init__(self, dim, heads = 8, dim_head = 64, dropout = 0.):
        super().__init__()
        inner_dim = dim_head *  heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim = -1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        #把head的个数赋值给h
        b, n, _, h = *x.shape, self.heads
        qkv = self.to_qkv(x).chunk(3, dim = -1)
        #得到qkv
        # h指的是有几个head， dim = 1024, head=8, dim_per_head = 1024/8 = 128
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h = h), qkv)

        dots = einsum('b h i d, b h j d -> b h i j', q, k) * self.scale

        # self.attend是softmax
        attn = self.attend(dots)
        
        
        # 整合head
        out = einsum('b h i j, b h j d -> b h i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

# %% [markdown]
# #### 2.2.3 得到QKV
# ![image.png](attachment:image.png)
# 关键代码：

# %%
self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)
qkv = self.to_qkv(x).chunk(3, dim = -1)

# %% [markdown]
# #### 2.2.4 QK 矩阵乘法
# ![image.png](attachment:image.png)
# 关键代码：

# %%
dots = einsum('b h i d, b h j d -> b h i j', q, k) * self.scale

# %% [markdown]
# #### 2.2.5 新value计算
# ![image.png](attachment:image.png)
# 关键代码：

# %%
attn = self.attend(dots)
out = einsum('b h i j, b h j d -> b h i d', attn, v)
out = rearrange(out, 'b h n d -> b n (h d)')

# %% [markdown]
# #### 2.2.6 Wo
# ![image.png](attachment:image.png)
# 关键代码

# %%
self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

# %% [markdown]
# ### 2.3 FeedForward
# 关键代码：

# %%
class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# # 3. 回顾代码
# 对一下各个部分的shape

# %% [markdown]
# # 4. 实际使用的例子
# source: https://github.com/lucidrains/vit-pytorch/blob/main/examples/cats_and_dogs.ipynb

# %% [markdown]
# # 5. 总结
